# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.array([807, 2042, 3046, 4563, 7059, 
              10537, 14841, 20478, 23078, 23692, 26235,29452,
             35385, 39197, 42913])

# %%
plt.plot(y)

# %%
a = np.ones(len(y))
for i in range(1, len(y)):
    a[i -1] = y[i] - y[i-1]

# %%
a
# Out:
# array([1.235e+03, 1.004e+03, 1.517e+03, 2.496e+03, 3.478e+03, 4.304e+03,
#        5.637e+03, 2.600e+03, 6.140e+02, 2.543e+03, 3.217e+03, 5.933e+03,
#        3.812e+03, 3.716e+03, 1.000e+00])

# %%
plt.plot(a)
plt.axhline(a.mean())

# %%
a.mean() # a cada dia, novas 2807 pessoas sao vacinadas
# Out:
# 2807.133333333333

# %%
2807 + 42913 #previsao do numero de vacionados em 07/02
# Out:
# 45720

# %%
(46024 + 45720)/2
# Out:
# 45872.0
